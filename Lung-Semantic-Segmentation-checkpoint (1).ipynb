# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from PIL import Image

# %%
import numpy as np

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:52, in <module>
#      50 from ._api.v2 import autograph
#      51 from ._api.v2 import bitwise
# ---> 52 from ._api.v2 import compat
#      53 from ._api.v2 import config
#      54 from ._api.v2 import data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\__init__.py:37, in <module>
#       3 """Compatibility functions.
#       4
#       5 The `tf.compat` module contains two sets of compatibility functions.
#    (...)
#      32
#      33 """
#      35 import sys as _sys
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:31, in <module>
#      29 from . import autograph
#      30 from . import bitwise
# ---> 31 from . import compat
#      32 from . import config
#      33 from . import data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:38, in <module>
#      35 import sys as _sys
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v1\compat\v2\__init__.py:28, in <module>
#      25 # pylint: disable=g-bad-import-order
#      27 from . import compat
# ---> 28 from tensorflow._api.v2.compat.v2 import __internal__
#      29 from tensorflow._api.v2.compat.v2 import __operators__
#      30 from tensorflow._api.v2.compat.v2 import audio
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\__init__.py:33, in <module>
#      31 from . import autograph
#      32 from . import bitwise
# ---> 33 from . import compat
#      34 from . import config
#      35 from . import data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\compat\__init__.py:38, in <module>
#      35 import sys as _sys
#      37 from . import v1
# ---> 38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      40 from tensorflow.python.compat.compat import forward_compatible
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\compat\v2\__init__.py:335, in <module>
#     333 _current_module = _sys.modules[__name__]
#     334 try:
# --> 335   from tensorboard.summary._tf import summary
#     336   _current_module.__path__ = (
#     337       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#     338   setattr(_current_module, "summary", summary)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\summary\__init__.py:22, in <module>
#      20 # If the V1 summary API is accessible, load and re-export it here.
#      21 try:
# ---> 22     from tensorboard.summary import v1  # noqa: F401
#      23 except ImportError:
#      24     pass
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\summary\v1.py:23, in <module>
#      21 from tensorboard.plugins.audio import summary as _audio_summary
#      22 from tensorboard.plugins.custom_scalar import summary as _custom_scalar_summary
# ---> 23 from tensorboard.plugins.histogram import summary as _histogram_summary
#      24 from tensorboard.plugins.image import summary as _image_summary
#      25 from tensorboard.plugins.pr_curve import summary as _pr_curve_summary
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\plugins\histogram\summary.py:35, in <module>
#      32 import numpy as np
#      34 from tensorboard.plugins.histogram import metadata
# ---> 35 from tensorboard.plugins.histogram import summary_v2
#      38 # Export V3 versions.
#      39 histogram = summary_v2.histogram
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\plugins\histogram\summary_v2.py:35, in <module>
#      33 from tensorboard.plugins.histogram import metadata
#      34 from tensorboard.util import lazy_tensor_creator
# ---> 35 from tensorboard.util import tensor_util
#      38 DEFAULT_BUCKET_COUNT = 30
#      41 def histogram_pb(tag, data, buckets=None, description=None):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\util\tensor_util.py:20, in <module>
#      17 import numpy as np
#      19 from tensorboard.compat.proto import tensor_pb2
# ---> 20 from tensorboard.compat.tensorflow_stub import dtypes, compat, tensor_shape
#      23 def ExtractBitsFromFloat16(x):
#      24     return np.asarray(x, dtype=np.float16).view(np.uint16).item()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\__init__.py:22, in <module>
#      20 from tensorboard.compat.proto.meta_graph_pb2 import *  # noqa
#      21 from tensorboard.compat.proto.summary_pb2 import *  # noqa
# ---> 22 from .dtypes import as_dtype  # noqa
#      23 from .dtypes import DType  # noqa
#      24 from .dtypes import string  # noqa
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:19, in <module>
#      15 """Library of dtypes (Tensor element types)."""
#      17 import numpy as np
# ---> 19 from . import pywrap_tensorflow
#      20 from tensorboard.compat.proto import types_pb2
#      22 _np_bfloat16 = pywrap_tensorflow.TF_bfloat16_type()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\pywrap_tensorflow.py:22, in <module>
#      19 import struct
#      21 from . import errors
# ---> 22 from .io import gfile
#      25 TFE_DEVICE_PLACEMENT_WARN = 0
#      26 TFE_DEVICE_PLACEMENT_SILENT_FOR_INT32 = 0
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\io\__init__.py:17, in <module>
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
# ---> 17 from . import gfile
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py:33, in <module>
#      31 try:
#      32     import botocore.exceptions
# ---> 33     import boto3
#      35     S3_ENABLED = True
#      36 except ImportError:
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\boto3\__init__.py:17, in <module>
#      14 import logging
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#      20 __version__ = '1.21.32'
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\boto3\session.py:17, in <module>
#      14 import copy
#      15 import os
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#      19 from botocore.exceptions import DataNotFoundError, UnknownServiceError
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\session.py:26, in <module>
#      23 import socket
#      24 import warnings
# ---> 26 import botocore.client
#      27 import botocore.configloader
#      28 import botocore.credentials
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\client.py:15, in <module>
#       1 # Copyright 2014 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
#      13 import logging
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#      17 from botocore.auth import AUTH_TYPE_MAPS
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\waiter.py:18, in <module>
#      14 import time
#      16 import jmespath
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#      21 from . import xform_name
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\docs\__init__.py:15, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
#      13 import os
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      18 def generate_docs(root_dir, session):
#      19     """Generates the reference documentation for botocore
#      20
#      21     This will go through every available AWS service and output ReSTructured
#    (...)
#      26         root_dir/reference/services/service-name.rst
#      27     """
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\docs\service.py:14, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#      16 from botocore.docs.waiter import WaiterDocumenter
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\docs\client.py:14, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#      17     document_model_driven_method,
#      18     get_instance_public_methods,
#      19 )
#      20 from botocore.docs.params import ResponseParamsDocumenter
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\docs\example.py:13, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#      17 class BaseExampleDocumenter(ShapeDocumenter):
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\docs\shape.py:19, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      22 class ShapeDocumenter(object):
#      23     EVENT_NAME = ''
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\utils.py:34, in <module>
#      32 import botocore
#      33 import botocore.awsrequest
# ---> 34 import botocore.httpsession
#      35 from botocore.compat import (
#      36     HAS_CRT,
#      37     MD5_AVAILABLE,
#    (...)
#      47     zip_longest,
#      48 )
#      49 from botocore.exceptions import (
#      50     ClientError,
#      51     ConfigNotFound,
#    (...)
#      71     UnsupportedS3ControlConfigurationError,
#      72 )
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\botocore\httpsession.py:34, in <module>
#      30     from ssl import OP_NO_TICKET, PROTOCOL_TLS_CLIENT
#      32 try:
#      33     # Always import the original SSLContext, even if it has been patched
# ---> 34     from urllib3.contrib.pyopenssl import orig_util_SSLContext as SSLContext
#      35 except ImportError:
#      36     from urllib3.util.ssl_ import SSLContext
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\urllib3\contrib\pyopenssl.py:50, in <module>
#       1 """
#       2 TLS with SNI_-support for Python 2. Follow these instructions if you would
#       3 like to verify TLS certificates in Python 2. Note, the default libraries do
#    (...)
#      46 .. _idna: https://github.com/kjd/idna
#      47 """
#      48 from __future__ import absolute_import
# ---> 50 import OpenSSL.SSL
#      51 from cryptography import x509
#      52 from cryptography.hazmat.backends.openssl import backend as openssl_backend
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\OpenSSL\__init__.py:8, in <module>
#       1 # Copyright (C) AB Strakt
#       2 # See LICENSE for details.
#       4 """
#       5 pyOpenSSL - A simple wrapper around the OpenSSL library
#       6 """
# ----> 8 from OpenSSL import crypto, SSL
#       9 from OpenSSL.version import (
#      10     __author__,
#      11     __copyright__,
#    (...)
#      17     __version__,
#      18 )
#      21 __all__ = [
#      22     "SSL",
#      23     "crypto",
#    (...)
#      31     "__version__",
#      32 ]
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\OpenSSL\crypto.py:1579, in <module>
#    1575         ext._extension = _ffi.gc(extension, _lib.X509_EXTENSION_free)
#    1576         return ext
# -> 1579 class X509StoreFlags(object):
#    1580     """
#    1581     Flags for X509 verification, used to change the behavior of
#    1582     :class:`X509Store`.
#    (...)
#    1587         https://www.openssl.org/docs/manmaster/man3/X509_VERIFY_PARAM_set_flags.html
#    1588     """
#    1590     CRL_CHECK = _lib.X509_V_FLAG_CRL_CHECK
#
# File C:\ProgramData\Anaconda3\envs\python39\lib\site-packages\OpenSSL\crypto.py:1598, in X509StoreFlags()
#    1596 EXPLICIT_POLICY = _lib.X509_V_FLAG_EXPLICIT_POLICY
#    1597 INHIBIT_MAP = _lib.X509_V_FLAG_INHIBIT_MAP
# -> 1598 NOTIFY_POLICY = _lib.X509_V_FLAG_NOTIFY_POLICY
#    1599 CHECK_SS_SIGNATURE = _lib.X509_V_FLAG_CHECK_SS_SIGNATURE
#
# AttributeError: module 'lib' has no attribute 'X509_V_FLAG_NOTIFY_POLICY'

# %%
from tensorflow.keras.models import Model, load_model

# %%
from tensorflow.keras.layers import Conv2D, Input, Concatenate, MaxPooling2D, Conv2DTranspose

# %%
import numpy as np

# %%
import os

# %%
import cv2

# %%
import pickle

# %%
train_fpath='Dataset/images/'
train_masks_fpath='Dataset/masks/'

# %%
print("No. of images =",len(os.listdir(train_fpath)))
print("No. of image masks =",len(os.listdir(train_masks_fpath)))

# %%
def plot_img_and_mask(id):
    img = cv2.imread(train_fpath + id + '.tif')
    img_mask = cv2.imread(train_masks_fpath + id + '.tif')
    plt.figure(figsize=(10,10))
    plt.subplot(1,3,1,title='Actual image')
    plt.imshow(img)
    plt.subplot(1,3,3,title='Image mask')
    plt.imshow(img_mask)
    
plot_img_and_mask('ID_0066_Z_0141')

# %%
plot_img_and_mask('ID_0202_Z_0098')

# %%
def initialize_img_data(folder):
    lst=[] 
    for image in os.listdir(folder):
        img= cv2.imread(folder+"/"+image, cv2.IMREAD_GRAYSCALE)
        img_array=Image.fromarray(img)
        resize_img = img_array.resize((128 , 128))
        norm_img=np.array(resize_img)/255
        img_array = norm_img.reshape((128,128,1))
        lst.append(img_array)
    return lst
    
X = initialize_img_data(train_fpath)
y = initialize_img_data(train_masks_fpath)

# %%
print(len(os.listdir(train_fpath)),len(X),len(y))
print(X[0].shape,y[0].shape)

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,3,1,title='Actual image')
plt.imshow(X[10],cmap="gray")

plt.subplot(1,3,3,title='Image mask')
plt.imshow(y[10],cmap="gray")

# %%
X = np.array(X)
y = np.array(y)

# %%
x_train = X[:200]
y_train = y[:200]

x_test = X[200:]
y_test = y[200:]

# %%
def create_proposed_model():
    inputs = Input(shape=(128, 128, 1))

    c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (inputs)
    c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
    c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
    c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
    c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
    c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = Concatenate()([u6, c4])
    c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
    c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

    u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = Concatenate()([u7, c3])
    c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
    c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

    u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = Concatenate()([u8, c2])
    c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
    c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

    u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = Concatenate()([u9, c1]) 
    c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
    c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
model = create_proposed_model()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')
model.summary()

# %%
x_train.shape

# %%
early_stop = EarlyStopping(monitor='loss', patience=5)
check_point = ModelCheckpoint("model.hdf5", monitor='loss', save_best_only=True)

# %%
can_train = True

# %%
if can_train:
    history = model.fit(x_train, y_train, epochs=200, callbacks=[early_stop,check_point], validation_split=0.2)
    model.save("Lung-Semantic-Segmentation-Model.keras")
    with open("Lung-Semantic-Segmentation-History.pickle", "wb") as fs:
        pickle.dump(history.history, fs)
    history = history.history
else:
    model = load_model("Lung-Semantic-Segmentation-Model.keras")
    with open("Lung-Semantic-Segmentation-History.pickle", "rb") as fs:
        history = pickle.load(fs)

# %%
pred_test = model.predict(x_test, verbose=1)

# %%
x_test = np.squeeze(x_test,axis=-1)
pred_test = np.squeeze(pred_test,axis=-1)

print(x_test.shape, pred_test.shape)

# %%
plt.figure(1 , figsize = (15, 9))
n = 0 
for i in range(4):
    n += 1 
    r=[i]
    plt.subplot(2, 2, n)
    plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
    plt.imshow(x_test[r[0]], cmap="gray")
    plt.imshow(pred_test[r[0]], alpha=0.5, cmap="Oranges")
    

plt.suptitle("Lung images and the masks predicted by proposed model highlighted in RED")
plt.show()

# %%
plt.figure(1 , figsize = (15, 9))
n = 0 
for i in range(4):
    n += 1 
    r=[i]
    plt.subplot(2, 2, n)
    plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
    plt.imshow(x_test[r[0]], cmap="gray")
    plt.imshow(y_test[r[0]], alpha=0.5, cmap="Oranges")
    

plt.suptitle("Lung images and the masks predicted by proposed model highlighted in RED")
plt.show()
